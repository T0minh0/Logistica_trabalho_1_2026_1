# %% [markdown]
# # 01. Pré-processamento
#
# Este notebook lida com o carregamento dos dados brutos M5, filtragem baseada no escopo do projeto (lojas, categorias), transformação para formato long (melt) e engenharia de features.

# %%
import sys
import os
sys.path.append('..')

from src.io_load import load_m5_data
from src.preprocess import preprocess_data
from src.config import RESULTS_DIR

# Carregar Dados
sales_raw, calendar, prices = load_m5_data()

# Pré-processar
df = preprocess_data(sales_raw, calendar, prices)

# Visualizar
df.head()

# %%
# Salvar resultado intermediário (opcional)
# df.to_pickle(RESULTS_DIR / 'processed_data.pkl')
